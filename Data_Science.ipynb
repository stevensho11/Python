# %% [markdown]
# <a href="https://colab.research.google.com/github/stevensho11/BCS109/blob/master/Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

df = pd.read_csv("https://raw.githubusercontent.com/stevensho11/BCS109/master/datascience1/airline-safety.csv")
df.head()
# Out:
#                  airline  ...  fatalities_00_14
# 0             Aer Lingus  ...                 0
# 1              Aeroflot*  ...                88
# 2  Aerolineas Argentinas  ...                 0
# 3            Aeromexico*  ...                 0
# 4             Air Canada  ...                 0
#
# [5 rows x 8 columns]

# %%
#check for nulls
df.isnull().sum()
# Out:
# airline                   0
# avail_seat_km_per_week    0
# incidents_85_99           0
# fatal_accidents_85_99     0
# fatalities_85_99          0
# incidents_00_14           0
# fatal_accidents_00_14     0
# fatalities_00_14          0
# dtype: int64

# %%
#list number of unique values
df.nunique()
# Out:
# airline                   56
# avail_seat_km_per_week    56
# incidents_85_99           19
# fatal_accidents_85_99     11
# fatalities_85_99          38
# incidents_00_14           14
# fatal_accidents_00_14      4
# fatalities_00_14          23
# dtype: int64

# %%
#stats on my data
df.describe()
# Out:
#        avail_seat_km_per_week  ...  fatalities_00_14
# count            5.600000e+01  ...         56.000000
# mean             1.384621e+09  ...         55.517857
# std              1.465317e+09  ...        111.332751
# min              2.593733e+08  ...          0.000000
# 25%              4.740362e+08  ...          0.000000
# 50%              8.029089e+08  ...          0.000000
# 75%              1.847239e+09  ...         83.250000
# max              7.139291e+09  ...        537.000000
#
# [8 rows x 7 columns]

# %%
#check scale
sns.catplot(data=df, kind='box', height=3, aspect=4.1)

# %%
#barplot - airlines and the number of incidents had during 2000-2014
bp = sns.catplot(x = 'incidents_00_14', y = 'airline', data =df, kind='bar', height = 7.8, aspect=2.1)

# %%
#plots
sns.catplot(x='incidents_00_14', data=df, kind='count', height=3, aspect=2.1)
sns.catplot(x='fatalities_00_14', data=df, kind='count', height=3, aspect=2.5)

# %%
#histograms
df.hist(figsize=(20, 20), bins=10, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efbd99ae9b0>,
# ...
#       dtype=object)

# %%
#swarmplot - avail seats per week vs # incidents
swarmdf = sns.swarmplot(x="incidents_00_14", y="avail_seat_km_per_week", data=df)

# %%
#creating new df2 dataset
df2 = df.drop(['airline', ], axis = 1)
df2.head()
# Out:
#    avail_seat_km_per_week  ...  fatalities_00_14
# 0               320906734  ...                 0
# 1              1197672318  ...                88
# 2               385803648  ...                 0
# 3               596871813  ...                 0
# 4              1865253802  ...                 0
#
# [5 rows x 7 columns]

# %%
#heatmap
corr = df.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data=corr, square=True, annot=True, cbar=True, ax=ax)
